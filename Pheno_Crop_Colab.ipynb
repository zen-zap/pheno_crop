# %% [markdown]
# <a href="https://colab.research.google.com/github/zen-zap/pheno_crop/blob/main/Pheno_Crop_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# GEE setup

import ee

ee.Authenticate()

ee.Initialize(project='pheno-crop-489815')
print("Earth Engine Initialized Successfully!")
# Out:
# Earth Engine Initialized Successfully!
